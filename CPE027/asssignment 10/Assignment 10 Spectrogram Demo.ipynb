# %% [markdown]
# # Assignment 10: Spectrogram Demo.ipynb

# %%
## Importing libraries
import os
import matplotlib.pyplot as plt

## for loading and visualizing audio files
import librosa
import librosa.display

## to play audio
from IPython.display import Audio 
from IPython.core.display import display
# Out:
# C:\Users\My Pc\AppData\Local\Temp\ipykernel_19756\1519729696.py:11: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display

# %%
## Loading the audio file
x, sr = librosa.load('goat_cat_meme.wav', sr=44100)

print(type(x), type(sr))
print(x.shape, sr)
# Out:
# <class 'numpy.ndarray'> <class 'int'>
# (407552,) 44100

# %%
## Graphing the audio file
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
## Playing the graphed audio
display(Audio('goat_cat_meme.wav', autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
